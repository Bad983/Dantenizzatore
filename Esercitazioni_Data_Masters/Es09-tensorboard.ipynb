# %% [markdown]
# Esempio di Log su **TensorBoard** di un addestramento

# %%
# importazione librerie necessarie
import tensorflow as tf
import datetime

# %%
# Usando il set di dati MNIST come esempio,
# logghiamo un addestramento su TensorBoard

mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

def create_model():
  return tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(16, activation='sigmoid', kernel_initializer=tf.keras.initializers.RandomUniform()),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(32, activation='sigmoid', kernel_initializer=tf.keras.initializers.RandomUniform()),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation='sigmoid', kernel_initializer=tf.keras.initializers.RandomUniform()),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation='softmax')
  ])

model = create_model()
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 16)                12560
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 32)                544
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 15,866
# Trainable params: 15,866
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Utilizzo di TensorBoard con Keras
# -------------
# Addestrando con il metodo fit() di
# Keras, l'aggiunta di un callback
# tf.keras.callbacks.TensorBoard garantisce
# la creazione e l'archiviazione dei
# log di addestramento.
# Impostando il parametro histogram_freq=1
# (di default è disattivato) è possibile
# loggare anche le distribuzioni dei pesi
# del modello

# Posiziona i log in una sottodirectory
# con il timestamp nel nome per consentire
# una facile selezione di diverse sessioni
# di addestramento.
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# addestramento con log tramite
# callback a TensorBoard
model.fit(x=x_train,
          y=y_train,
          epochs=50,
          batch_size=4096,
          validation_data=(x_test, y_test),
          callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 15/15 [==============================] - 1s 39ms/step - loss: 2.6785 - accuracy: 0.0982 - val_loss: 2.3539 - val_accuracy: 0.0980
# Epoch 2/50
# 15/15 [==============================] - 0s 23ms/step - loss: 2.4764 - accuracy: 0.1025 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 3/50
# 15/15 [==============================] - 0s 24ms/step - loss: 2.4268 - accuracy: 0.1015 - val_loss: 2.2991 - val_accuracy: 0.1028
# Epoch 4/50
# 15/15 [==============================] - 0s 24ms/step - loss: 2.3927 - accuracy: 0.1017 - val_loss: 2.2943 - val_accuracy: 0.1194
# Epoch 5/50
# 15/15 [==============================] - 0s 23ms/step - loss: 2.3639 - accuracy: 0.1050 - val_loss: 2.2905 - val_accuracy: 0.1257
# Epoch 6/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.3438 - accuracy: 0.1072 - val_loss: 2.2860 - val_accuracy: 0.1809
# Epoch 7/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.3302 - accuracy: 0.1085 - val_loss: 2.2797 - val_accuracy: 0.1962
# Epoch 8/50
# 15/15 [==============================] - 0s 24ms/step - loss: 2.3178 - accuracy: 0.1125 - val_loss: 2.2715 - val_accuracy: 0.2018
# Epoch 9/50
# 15/15 [==============================] - 0s 23ms/step - loss: 2.3030 - accuracy: 0.1199 - val_loss: 2.2611 - val_accuracy: 0.2132
# Epoch 10/50
# 15/15 [==============================] - 0s 23ms/step - loss: 2.2909 - accuracy: 0.1252 - val_loss: 2.2482 - val_accuracy: 0.2221
# Epoch 11/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.2759 - accuracy: 0.1320 - val_loss: 2.2327 - val_accuracy: 0.1991
# Epoch 12/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.2595 - accuracy: 0.1383 - val_loss: 2.2146 - val_accuracy: 0.2028
# Epoch 13/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.2420 - accuracy: 0.1481 - val_loss: 2.1944 - val_accuracy: 0.2038
# Epoch 14/50
# 15/15 [==============================] - 0s 25ms/step - loss: 2.2253 - accuracy: 0.1500 - val_loss: 2.1726 - val_accuracy: 0.2046
# Epoch 15/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.2050 - accuracy: 0.1567 - val_loss: 2.1496 - val_accuracy: 0.2050
# Epoch 16/50
# 15/15 [==============================] - 0s 23ms/step - loss: 2.1846 - accuracy: 0.1622 - val_loss: 2.1266 - val_accuracy: 0.2052
# Epoch 17/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.1651 - accuracy: 0.1678 - val_loss: 2.1038 - val_accuracy: 0.2053
# Epoch 18/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.1480 - accuracy: 0.1697 - val_loss: 2.0819 - val_accuracy: 0.2052
# Epoch 19/50
# 15/15 [==============================] - 0s 23ms/step - loss: 2.1278 - accuracy: 0.1750 - val_loss: 2.0611 - val_accuracy: 0.2052
# Epoch 20/50
# 15/15 [==============================] - 0s 23ms/step - loss: 2.1093 - accuracy: 0.1756 - val_loss: 2.0410 - val_accuracy: 0.2075
# Epoch 21/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.0922 - accuracy: 0.1792 - val_loss: 2.0224 - val_accuracy: 0.2082
# Epoch 22/50
# 15/15 [==============================] - 0s 23ms/step - loss: 2.0771 - accuracy: 0.1808 - val_loss: 2.0048 - val_accuracy: 0.2094
# Epoch 23/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.0608 - accuracy: 0.1838 - val_loss: 1.9881 - val_accuracy: 0.2100
# Epoch 24/50
# 15/15 [==============================] - 0s 21ms/step - loss: 2.0480 - accuracy: 0.1826 - val_loss: 1.9728 - val_accuracy: 0.2111
# Epoch 25/50
# 15/15 [==============================] - 0s 23ms/step - loss: 2.0307 - accuracy: 0.1852 - val_loss: 1.9581 - val_accuracy: 0.2120
# Epoch 26/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.0203 - accuracy: 0.1877 - val_loss: 1.9444 - val_accuracy: 0.2116
# Epoch 27/50
# 15/15 [==============================] - 0s 22ms/step - loss: 2.0084 - accuracy: 0.1894 - val_loss: 1.9316 - val_accuracy: 0.2125
# Epoch 28/50
# 15/15 [==============================] - 0s 24ms/step - loss: 1.9977 - accuracy: 0.1924 - val_loss: 1.9197 - val_accuracy: 0.2123
# Epoch 29/50
# 15/15 [==============================] - 0s 24ms/step - loss: 1.9874 - accuracy: 0.1928 - val_loss: 1.9092 - val_accuracy: 0.2134
# Epoch 30/50
# 15/15 [==============================] - 0s 24ms/step - loss: 1.9756 - accuracy: 0.1963 - val_loss: 1.8988 - val_accuracy: 0.2043
# Epoch 31/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.9679 - accuracy: 0.1949 - val_loss: 1.8890 - val_accuracy: 0.2134
# Epoch 32/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.9574 - accuracy: 0.1953 - val_loss: 1.8804 - val_accuracy: 0.2134
# Epoch 33/50
# 15/15 [==============================] - 0s 22ms/step - loss: 1.9504 - accuracy: 0.1953 - val_loss: 1.8721 - val_accuracy: 0.2128
# Epoch 34/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.9403 - accuracy: 0.1965 - val_loss: 1.8643 - val_accuracy: 0.2134
# Epoch 35/50
# 15/15 [==============================] - 0s 22ms/step - loss: 1.9341 - accuracy: 0.1983 - val_loss: 1.8577 - val_accuracy: 0.2135
# Epoch 36/50
# 15/15 [==============================] - 0s 24ms/step - loss: 1.9268 - accuracy: 0.2008 - val_loss: 1.8507 - val_accuracy: 0.2137
# Epoch 37/50
# 15/15 [==============================] - 0s 22ms/step - loss: 1.9218 - accuracy: 0.1976 - val_loss: 1.8455 - val_accuracy: 0.2142
# Epoch 38/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.9150 - accuracy: 0.1985 - val_loss: 1.8396 - val_accuracy: 0.2136
# Epoch 39/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.9069 - accuracy: 0.2025 - val_loss: 1.8345 - val_accuracy: 0.2139
# Epoch 40/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.9025 - accuracy: 0.1995 - val_loss: 1.8299 - val_accuracy: 0.2132
# Epoch 41/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.8956 - accuracy: 0.2004 - val_loss: 1.8257 - val_accuracy: 0.2133
# Epoch 42/50
# 15/15 [==============================] - 0s 22ms/step - loss: 1.8940 - accuracy: 0.2031 - val_loss: 1.8211 - val_accuracy: 0.2154
# Epoch 43/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.8884 - accuracy: 0.2012 - val_loss: 1.8171 - val_accuracy: 0.2142
# Epoch 44/50
# 15/15 [==============================] - 0s 22ms/step - loss: 1.8835 - accuracy: 0.2008 - val_loss: 1.8143 - val_accuracy: 0.2164
# Epoch 45/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.8774 - accuracy: 0.2029 - val_loss: 1.8100 - val_accuracy: 0.2140
# Epoch 46/50
# 15/15 [==============================] - 0s 22ms/step - loss: 1.8760 - accuracy: 0.2021 - val_loss: 1.8073 - val_accuracy: 0.2147
# Epoch 47/50
# 15/15 [==============================] - 0s 23ms/step - loss: 1.8711 - accuracy: 0.2055 - val_loss: 1.8044 - val_accuracy: 0.2147
# Epoch 48/50
# 15/15 [==============================] - 0s 22ms/step - loss: 1.8679 - accuracy: 0.2024 - val_loss: 1.8020 - val_accuracy: 0.2147
# Epoch 49/50
# 15/15 [==============================] - 0s 22ms/step - loss: 1.8652 - accuracy: 0.2055 - val_loss: 1.7992 - val_accuracy: 0.2170
# Epoch 50/50
# 15/15 [==============================] - 0s 22ms/step - loss: 1.8611 - accuracy: 0.2033 - val_loss: 1.7970 - val_accuracy: 0.2173

# %% [markdown]
# eseguito lo script, in una shell avviare
# Tensorboard con il seguente comando
# nella stessa cartella in cui è salvato
# questo jupyter notebook
# ```
# (venv) C:\....\tensorboard --logdir logs/fit
# ```
